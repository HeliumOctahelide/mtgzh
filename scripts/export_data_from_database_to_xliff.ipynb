# %% [markdown]
# # 将数据从SQLite数据库导出为XLIFF翻译文件
#
# 修改路径后依次运行下列代码块即可。适用于Linux环境，Windows环境下未经测试。

# %%
from lxml import etree
from sqlalchemy import create_engine, text
import os
from datetime import datetime

WORKDIR = "/mnt/f/OneDrive/cs/mtgdatabase/weblate_database/mtgzh"
DATABASEDIR = "/mnt/f/OneDrive/cs/mtgdatabase/"

ATOMIC_SQL_TEXT = """SELECT 
    scryfallId, 
    atomicCards.*,
    COALESCE(sets.parentCode, cards.setCode) AS parent_code,
    COALESCE(parentSets.releaseDate, sets.releaseDate) AS releaseDate,
    NULL,
    NULL
FROM 
    atomicCards 
INNER JOIN 
    cards 
ON 
    atomicCards.name = COALESCE(cards.faceName, cards.name) 
    AND atomicCards.setCode = cards.setCode 
    AND atomicCards.number = cards.number 
INNER JOIN 
    cardIdentifiers 
ON 
    cardIdentifiers.uuid = cards.uuid
INNER JOIN
    sets
ON 
    sets.code = cards.setCode
LEFT JOIN 
    sets parentSets 
ON 
    parentSets.code = sets.parentCode"""

ALL_SQL_TEXT = """SELECT 
    scryfallId, 
    COALESCE(c.faceName, c.name) AS name,
    NULL,
    c.setCode,
    c.number,
    COALESCE(c.originalText, c.text) AS text,
    NULL,
    COALESCE(z.faceName, z.name) AS zhsName,
    z.text AS zhsText,
    NULL,
    NULL,
    NULL,
    NULL,
    NULL,
    NULL,
    z.extra,
    COALESCE(sets.parentCode, c.setCode) AS parent_code,
    COALESCE(parentSets.releaseDate, sets.releaseDate) AS releaseDate,
    c.flavorText,
    z.flavorText AS zhsFlavorText
FROM 
    cards c 
LEFT JOIN
    zhs z ON z.uuid = c.uuid
INNER JOIN 
    cardIdentifiers ON cardIdentifiers.uuid = c.uuid
INNER JOIN
    sets ON sets.code = c.setCode
LEFT JOIN 
    sets parentSets ON parentSets.code = sets.parentCode"""

def escape_xml(s, without_quote=False):
    return s.replace("&", "&amp;").replace("<", "&lt;").replace(">", "&gt;").replace("\"", "&quot;") if not without_quote else s.replace("&", "&amp;").replace("<", "&lt;").replace(">", "&gt;")

def unescape_xml(s):
    return s.replace("&amp;", "&").replace("&lt;", "<").replace("&gt;", ">").replace("&quot;", "\"").replace("\\n", "\n")

def read_table(sql_text):
    engine = create_engine(f'sqlite:////{DATABASEDIR}/zhs.sqlite')
    data = []
    with engine.connect() as connection:
        s = connection.execute(text(sql_text))
        for row in s:
            data.append({
                "scryfallId": row[0],
                "name": escape_xml(row[1]),
                "setCode": row[3],
                "number": row[4],
                "text": escape_xml(row[5].strip().replace(row[1], "CARDNAME") if row[5] else ""),
                "zhsName": escape_xml(row[7] if row[7] else ""),
                "zhsText": escape_xml(row[8].strip().replace(row[7], "CARDNAME") if row[8] else ""),
                "zhsUpdatedAt": row[9],
                "zhsUpdatedFrom": row[10],
                "translatedName": escape_xml(row[11] if row[11] else ""),
                "translatedText": escape_xml(row[12].strip().replace(row[7] or row[11] or "", "CARDNAME") if row[12] else ""),
                "translatedAt": row[13],
                "translatedFrom": row[14],
                "extra": row[15],
                "sortCode": f"{row[17]}-{row[16]}",
                "flavorText": escape_xml(row[18] if row[18] else ""),
                "zhsFlavorText": escape_xml(row[19] if row[19] else "")
            })
    return data

def sort_data_by_set(data):
    sorted_data = {}
    for row in data:
        if row['sortCode'] not in sorted_data:
            sorted_data[row['sortCode']] = []
        sorted_data[row['sortCode']].append(row)
    return sorted_data

def create_xliff_tree():
    '''
    创建一个xliff树，返回根节点
    '''
    root = etree.Element("xliff", xmlns="urn:oasis:names:tc:xliff:document:1.1")
    file_elem = etree.SubElement(root, "file")
    body = etree.SubElement(file_elem, "body")

    return root, body

def add_trans_unit(
    en_tree,
    zh_tree,
    data
):
    '''
    读取英文和中文的翻译，将其添加到对应的xliff树中。除了元数据外的内容都不是必须的。
    '''
    note = []
    if data['zhsUpdatedAt'] and data['zhsUpdatedFrom'] and data['setCode'] != data['zhsUpdatedFrom']:
        note.append(f"官方翻译于{data['zhsUpdatedFrom']}（{data['zhsUpdatedAt']}）")
    if data['translatedAt'] and data['translatedFrom']:
        note.append(f"非官方翻译于{data['translatedFrom']}（{data['translatedAt']}）")
    if data['extra']:
        note.append(data['extra'])
    note = "；".join(note)

    trans_unit = etree.SubElement(en_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Card Name", approved="yes")
    etree.SubElement(trans_unit, "source").text = data['name']
    etree.SubElement(trans_unit, "target", state="translated").text = data['name']

    if data['zhsName'] or data['translatedName']:
        if (data['translatedAt'] or "1900-01-01") > (data['zhsUpdatedAt'] or "1900-01-01"):
            zh_name = data['translatedName']
            zh_state = "needs-adaptation" if data['translatedFrom'] != "MTGZH" else "final"
            approved = "no" if data['translatedFrom'] != "MTGZH" else "yes"
        else:
            zh_name = data['zhsName']
            zh_state = "translated"
            approved = "no"
        trans_unit = etree.SubElement(zh_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Card Name", approved=approved)
        etree.SubElement(trans_unit, "source").text = data['name']
        etree.SubElement(trans_unit, "target", state=zh_state).text = zh_name
        if note: etree.SubElement(trans_unit, "note", nsmap={'from': "developer"}).text = note

    if data['text']:
        if (data['translatedAt'] or "1900-01-01") > (data['zhsUpdatedAt'] or "1900-01-01"):
            zh_text = data['translatedText']
            zh_state = "needs-adaptation" if data['translatedFrom'] != "MTGZH" else "final"
            approved = "no" if data['translatedFrom'] != "MTGZH" else "yes"
        elif data['zhsText']:
            zh_text = data['zhsText']
            zh_state = "translated"
            approved = "no"
        else:
            zh_text = ""
            
        if zh_text:
            # 如果存在中文，且中文和英文的行数无法对齐，则将所有行作为一个整体翻译（表现为Paragraphs）
            if zh_text.count("\\n") != data['text'].count("\\n"):
                trans_unit = etree.SubElement(en_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Card Text | Paragraphs", approved="yes")
                etree.SubElement(trans_unit, "source").text = data['text']
                etree.SubElement(trans_unit, "target", state="translated").text = data['text']

                trans_unit = etree.SubElement(zh_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Card Text | Paragraphs", approved=approved)
                etree.SubElement(trans_unit, "source").text = data['text']
                etree.SubElement(trans_unit, "target", state=zh_state).text = zh_text
                if note: etree.SubElement(trans_unit, "note", nsmap={'from': "developer"}).text = note
            # 如果中文和英文能够对齐，则将每行作为一个段落翻译
            else:
                for i, en_para, zh_para in zip(range(data['text'].count("\\n")+1), data['text'].split("\\n"), zh_text.split("\\n")):
                    trans_unit = etree.SubElement(en_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Card Text | Paragraph {i+1}", approved="yes")
                    etree.SubElement(trans_unit, "source").text = en_para
                    etree.SubElement(trans_unit, "target", state="translated").text = en_para

                    trans_unit = etree.SubElement(zh_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Card Text | Paragraph {i+1}", approved=approved)
                    etree.SubElement(trans_unit, "source").text = en_para
                    etree.SubElement(trans_unit, "target", state=zh_state).text = zh_para
                    if note: etree.SubElement(trans_unit, "note", nsmap={'from': "developer"}).text = note
        else:
            # 如果不存在中文，那就不需要考虑行数对齐的问题，直接分段落翻译
            for i, en_para in enumerate(data['text'].split("\\n")):
                trans_unit = etree.SubElement(en_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Card Text | Paragraph {i+1}", approved="yes")
                etree.SubElement(trans_unit, "source").text = en_para
                etree.SubElement(trans_unit, "target", state="translated").text = en_para

    if 'flavorText' in data and data['flavorText']:
        # 背景叙述永远作为一个整体翻译
        trans_unit = etree.SubElement(en_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Flavor Text", approved="yes")
        etree.SubElement(trans_unit, "source").text = data['flavorText']
        etree.SubElement(trans_unit, "target", state="translated").text = data['flavorText']

        if data['zhsFlavorText']:
            # 从数据库中取出的背景叙述均认为是被接受的（approved="yes"）
            trans_unit = etree.SubElement(zh_tree, "trans-unit", id=data['scryfallId'], resname=f"{data['setCode']}·{data['number']} | {data['name']} | Flavor Text", approved="yes")
            etree.SubElement(trans_unit, "source").text = data['flavorText']
            etree.SubElement(trans_unit, "target", state='translated').text = data['zhsFlavorText']
            if note: etree.SubElement(trans_unit, "note", nsmap={'from': "developer"}).text = note

def read_xliff_tree(file: str):
    '''
    将xliff树中的数据取出，返回原本的字典
    '''

    # 找到body节点
    tree = etree.parse(file)
    nsmap = {"ns": "urn:oasis:names:tc:xliff:document:1.1"}
    tree = tree.xpath("//ns:body", namespaces=nsmap)[0]
    tree = tree.xpath("/*/*/*/*")

    data = {}
    for node in tree:
        node_set_code_number, node_name, *node_types = node.attrib["resname"].split(" | ")
        if node_set_code_number not in data:
            data[node_set_code_number] = {
                "scryfallId": node.attrib["id"],
                "name": node_name,
                "setCode": node_set_code_number.split("·")[0],
                "number": node_set_code_number.split("·")[1],
                "extra": ""
            }
        card = data[node_set_code_number]
        target = node.xpath("ns:target", namespaces=nsmap)[0].text
        if node_types[0] == "Card Name":
            card['translatedName'] = unescape_xml(target)
        elif node_types[0] == "Card Text":
            if node_types[1] == "Paragraphs":
                card['translatedText'] = unescape_xml(target)
            else:
                if "translatedText" not in card:
                    card['translatedText'] = { node_types[1].split()[-1]: unescape_xml(target) }
                else:
                    card['translatedText'][node_types[1].split()[-1]] = unescape_xml(target)
        elif node_types[0] == "Flavor Text":
            card['zhsFlavorText'] = unescape_xml(target)

        # 预留备注的位置（暂时没有用上）
        '''
        is_note_from_developer = node.xpath("note")[0].attrib["xmlns:from"] == "developer"
        if is_note_from_developer:
            card['extra'] += unescape_xml(node.xpath("note")[0].text)
        '''

        card['translatedAt'] = datetime.fromtimestamp(os.path.getmtime(file)).strftime("%Y-%m-%d")
        card['translatedFrom'] = "MTGZH"

    # 字典形式的多行文本转化为字符串
    for card in data.values():
        if 'translatedText' in card and isinstance(card['translatedText'], dict):
            card['translatedText'] = "\\n".join([card['translatedText'][str(i+1)] for i in range(len(card['translatedText']))])

    return [card for card in data.values()]

REPLACED_SQL_TEXT = """SELECT
    *
FROM
    atomicCards
WHERE
    setCode = "{set_code}"
"""

UPDATE_NAME_TEXT = """UPDATE
    atomicCards
SET
    translatedName = :translatedName,
    translatedAt = :translatedAt,
    translatedFrom = :translatedFrom
WHERE
    name = :name
    AND setCode = :setCode
    AND number = :number
"""

UPDATE_TEXT_TEXT = """UPDATE
    atomicCards
SET
    translatedText = :translatedText,
    translatedAt = :translatedAt,
    translatedFrom = :translatedFrom
WHERE
    name = :name
    AND setCode = :setCode
    AND number = :number
"""

def replace_atomic_database(data, set_code):
    '''
    从xliff树中读取数据，将其写入atomicCards表
    目前需要传入set_code以确定要更新的数据
    '''
    engine = create_engine(f'sqlite:////{DATABASEDIR}/zhs.sqlite')
    with engine.connect() as connection:
        raw_data = connection.execute(text(REPLACED_SQL_TEXT.format(set_code=f'{set_code}'))).fetchall()
        raw_data = [dict(row) for row in raw_data]
    
    assert len(raw_data) == len(data), "数据长度不一致"
    
    data = sorted(data, key=lambda x: x['name'])
    raw_data = sorted(raw_data, key=lambda x: x['name'])

    assert [x['name'] for x in data] == [x['name'] for x in raw_data], "数据不一致"

    replacing_names = []
    replacing_texts = []
    for raw_card, updated_card in zip(raw_data, data):
        if updated_card['translatedAt'] < (raw_card['zhsUpdatedAt'] or ''):
            print(f"更新时间早于原数据更新时间，跳过：{updated_card['name']}")
            continue
        raw_name = raw_card['translatedName'] or raw_card['zhsName']
        raw_text = raw_card['translatedText'] or raw_card['zhsText']
        if updated_card.get('translatedName') and updated_card['translatedName'] != raw_name:
            print(f"将{updated_card['name']}的牌名加入更新队列")
            replacing_names.append(updated_card)
            card_name = updated_card['translatedName']
        else:
            card_name = raw_name
        if updated_card.get('translatedText') and updated_card['translatedText'] != raw_text:
            print(f"将{updated_card['name']}的文本加入更新队列")
            updated_card['translatedText'] = updated_card['translatedText'].replace("CARDNAME", card_name).replace("\n", "\\n")
            replacing_texts.append(updated_card)
            
    with engine.connect() as connection:
        for card in replacing_names:
            connection.execute(text(UPDATE_NAME_TEXT), card)
            print(f"已更新{card['name']}的牌名")
        for card in replacing_texts:
            connection.execute(text(UPDATE_TEXT_TEXT), card)
            print(f"已更新{card['name']}的文本")
        print(f"更新完成，更新了{len(replacing_names)}个牌名，{len(replacing_texts)}个文本")

# %% [markdown]
# ## 以下代码将XLIFF文件导入到数据库中

# %%
data = read_xliff_tree("../project/lang/zh_Hans/1996-10-08-MIR-Oracle.xliff")
replace_atomic_database(data, "MIR")
# Out:
# /tmp/ipykernel_12155/3145834119.py:303: RemovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   raw_data = [dict(row) for row in raw_data]
# 将Abyssal Hunter的文本加入更新队列
# 将Acidic Dagger的文本加入更新队列
# 将Afiya Grove的文本加入更新队列
# 将Afterlife的文本加入更新队列
# 将Agility的文本加入更新队列
# 将Alarum的文本加入更新队列
# 将Aleatory的文本加入更新队列
# 将Amber Prison的文本加入更新队列
# 将Amulet of Unmaking的文本加入更新队列
# 将Ancestral Memories的文本加入更新队列
# 将Armor of Thorns的文本加入更新队列
# 将Armorer Guildmage的文本加入更新队列
# 将Ashen Powder的文本加入更新队列
# 将Asmira, Holy Avenger的文本加入更新队列
# 将Auspicious Ancestor的文本加入更新队列
# 将Azimaet Drake的文本加入更新队列
# 将Bad River的文本加入更新队列
# 将Barbed Foliage的文本加入更新队列
# 将Barbed-Back Wurm的文本加入更新队列
# 将Barreling Attack的文本加入更新队列
# 将Basalt Golem的文本加入更新队列
# 将Bay Falcon的文本加入更新队列
# 将Bazaar of Wonders的文本加入更新队列
# 将Benevolent Unicorn的文本加入更新队列
# 将Benthic Djinn的文本加入更新队列
# 将Binding Agony的文本加入更新队列
# 将Blighted Shaman的文本加入更新队列
# 将Blind Fury的文本加入更新队列
# 将Blistering Barrier的文本加入更新队列
# 将Bone Harvest的文本加入更新队列
# 将Bone Mask的文本加入更新队列
# 将Breathstealer的文本加入更新队列
# 将Brushwagg的文本加入更新队列
# 将Builder's Bane的文本加入更新队列
# 将Burning Palm Efreet的文本加入更新队列
# 将Burning Shield Askari的文本加入更新队列
# 将Cadaverous Bloom的文本加入更新队列
# 将Cadaverous Knight的文本加入更新队列
# 将Canopy Dragon的文本加入更新队列
# 将Carrion的文本加入更新队列
# 将Catacomb Dragon的文本加入更新队列
# 将Celestial Dawn的文本加入更新队列
# 将Cerulean Wyvern的文本加入更新队列
# 将Chaos Charm的文本加入更新队列
# 将Chaosphere的文本加入更新队列
# 将Charcoal Diamond的文本加入更新队列
# 将Chariot of the Sun的文本加入更新队列
# 将Choking Sands的文本加入更新队列
# 将Cinder Cloud的文本加入更新队列
# 将Circle of Despair的文本加入更新队列
# 将Civic Guildmage的文本加入更新队列
# 将Cloak of Invisibility的文本加入更新队列
# 将Consuming Ferocity的文本加入更新队列
# 将Coral Fighters的文本加入更新队列
# 将Crash of Rhinos的文本加入更新队列
# 将Crimson Hellkite的文本加入更新队列
# 将Crimson Roc的文本加入更新队列
# 将Crypt Cobra的文本加入更新队列
# 将Crystal Golem的文本加入更新队列
# 将Crystal Vein的文本加入更新队列
# 将Cycle of Life的文本加入更新队列
# 将Daring Apprentice的文本加入更新队列
# 将Dazzling Beauty的文本加入更新队列
# 将Decomposition的文本加入更新队列
# 将Delirium的文本加入更新队列
# 将Dirtwater Wraith的文本加入更新队列
# 将Discordant Spirit的文本加入更新队列
# 将Disempower的文本加入更新队列
# 将Divine Retribution的文本加入更新队列
# 将Dread Specter的文本加入更新队列
# 将Dream Cache的文本加入更新队列
# 将Dream Fighter的文本加入更新队列
# 将Dwarven Miner的文本加入更新队列
# 将Dwarven Nomad的文本加入更新队列
# 将Early Harvest的文本加入更新队列
# 将Ebony Charm的文本加入更新队列
# 将Ekundu Cyclops的文本加入更新队列
# 将Elixir of Vitality的文本加入更新队列
# 将Emberwilde Caliph的文本加入更新队列
# 将Emberwilde Djinn的文本加入更新队列
# 将Energy Bolt的文本加入更新队列
# 将Energy Vortex的文本加入更新队列
# 将Enfeeblement的文本加入更新队列
# 将Ersatz Gnomes的文本加入更新队列
# 将Ether Well的文本加入更新队列
# 将Ethereal Champion的文本加入更新队列
# 将Favorable Destiny的文本加入更新队列
# 将Femeref Archers的文本加入更新队列
# 将Femeref Healer的文本加入更新队列
# 将Femeref Knight的文本加入更新队列
# 将Fetid Horror的文本加入更新队列
# 将Final Fortune的文本加入更新队列
# 将Fire Diamond的文本加入更新队列
# 将Flame Elemental的文本加入更新队列
# 将Flood Plain的文本加入更新队列
# 将Floodgate的文本加入更新队列
# 将Foratog的文本加入更新队列
# 将Forbidden Crypt的文本加入更新队列
# 将Forsaken Wastes的文本加入更新队列
# 将Frenetic Efreet的文本加入更新队列
# 将Gibbering Hyenas的文本加入更新队列
# 将Goblin Elite Infantry的文本加入更新队列
# 将Goblin Scouts的文本加入更新队列
# 将Goblin Soothsayer的文本加入更新队列
# 将Goblin Tinkerer的文本加入更新队列
# 将Granger Guildmage的文本加入更新队列
# 将Grasslands的文本加入更新队列
# 将Grave Servitude的文本加入更新队列
# 将Gravebane Zombie的文本加入更新队列
# 将Grim Feast的文本加入更新队列
# 将Grinning Totem的文本加入更新队列
# 将Hakim, Loreweaver的文本加入更新队列
# 将Hall of Gemstone的文本加入更新队列
# 将Hammer of Bogardan的文本加入更新队列
# 将Harbinger of Night的文本加入更新队列
# 将Harbor Guardian的文本加入更新队列
# 将Harmattan Efreet的文本加入更新队列
# 将Haunting Apparition的文本加入更新队列
# 将Hazerider Drake的文本加入更新队列
# 将Hivis of the Scale的文本加入更新队列
# 将Horrible Hordes的文本加入更新队列
# 将Igneous Golem的文本加入更新队列
# 将Illicit Auction的文本加入更新队列
# 将Illumination的文本加入更新队列
# 将Iron Tusk Elephant的文本加入更新队列
# 将Ivory Charm的文本加入更新队列
# 将Jabari's Influence的文本加入更新队列
# 将Jolrael's Centaur的文本加入更新队列
# 将Jolt的文本加入更新队列
# 将Jungle Patrol的文本加入更新队列
# 将Jungle Troll的文本加入更新队列
# 将Jungle Wurm的文本加入更新队列
# 将Kaervek's Hex的文本加入更新队列
# 将Kaervek's Purge的文本加入更新队列
# 将Kaervek's Torch的文本加入更新队列
# 将Karoo Meerkat的文本加入更新队列
# 将Kukemssa Pirates的文本加入更新队列
# 将Kukemssa Serpent的文本加入更新队列
# 将Lead Golem的文本加入更新队列
# 将Leering Gargoyle的文本加入更新队列
# 将Lightning Reflexes的文本加入更新队列
# 将Lion's Eye Diamond的文本加入更新队列
# 将Locust Swarm的文本加入更新队列
# 将Lure of Prey的文本加入更新队列
# 将Malignant Growth的文本加入更新队列
# 将Mana Prism的文本加入更新队列
# 将Mangara's Blessing的文本加入更新队列
# 将Mangara's Equity的文本加入更新队列
# 将Mangara's Tome的文本加入更新队列
# 将Marble Diamond的文本加入更新队列
# 将Maro的文本加入更新队列
# 将Meddle的文本加入更新队列
# 将Melesse Spirit的文本加入更新队列
# 将Merfolk Raiders的文本加入更新队列
# 将Merfolk Seer的文本加入更新队列
# 将Mind Bend的文本加入更新队列
# 将Mind Harness的文本加入更新队列
# 将Mindbender Spores的文本加入更新队列
# 将Mire Shade的文本加入更新队列
# 将Misers' Cage的文本加入更新队列
# 将Mist Dragon的文本加入更新队列
# 将Moss Diamond的文本加入更新队列
# 将Mountain Valley的文本加入更新队列
# 将Mtenda Griffin的文本加入更新队列
# 将Mtenda Herder的文本加入更新队列
# 将Mtenda Lion的文本加入更新队列
# 将Natural Balance的文本加入更新队列
# 将Nettletooth Djinn的文本加入更新队列
# 将Noble Elephant的文本加入更新队列
# 将Null Chamber的文本加入更新队列
# 将Patagia Golem的文本加入更新队列
# 将Paupers' Cage的文本加入更新队列
# 将Pearl Dragon的文本加入更新队列
# 将Phyrexian Dreadnought的文本加入更新队列
# 将Phyrexian Purge的文本加入更新队列
# 将Phyrexian Tribute的文本加入更新队列
# 将Political Trickery的文本加入更新队列
# 将Polymorph的文本加入更新队列
# 将Preferred Selection的文本加入更新队列
# 将Prismatic Boon的文本加入更新队列
# 将Prismatic Circle的文本加入更新队列
# 将Prismatic Lace的文本加入更新队列
# 将Psychic Transfer的文本加入更新队列
# 将Purgatory的文本加入更新队列
# 将Purraj of Urborg的文本加入更新队列
# 将Pyric Salamander的文本加入更新队列
# 将Quirion Elves的文本加入更新队列
# 将Radiant Essence的文本加入更新队列
# 将Raging Spirit的文本加入更新队列
# 更新时间早于原数据更新时间，跳过：Rampant Growth
# 将Rashida Scalebane的文本加入更新队列
# 将Ravenous Vampire的文本加入更新队列
# 将Razor Pendulum的文本加入更新队列
# 将Reality Ripple的文本加入更新队列
# 将Reckless Embermage的文本加入更新队列
# 将Reflect Damage的文本加入更新队列
# 将Reign of Chaos的文本加入更新队列
# 将Reign of Terror的文本加入更新队列
# 将Reparations的文本加入更新队列
# 将Restless Dead的文本加入更新队列
# 将Ritual of Steel的文本加入更新队列
# 将Rock Basilisk的文本加入更新队列
# 将Rocky Tar Pit的文本加入更新队列
# 将Roots of Life的文本加入更新队列
# 将Sabertooth Cobra的文本加入更新队列
# 将Sacred Mesa的文本加入更新队列
# 将Sand Golem的文本加入更新队列
# 将Sandbar Crocodile的文本加入更新队列
# 将Sapphire Charm的文本加入更新队列
# 将Savage Twister的文本加入更新队列
# 将Sawback Manticore的文本加入更新队列
# 将Sea Scryer的文本加入更新队列
# 将Sealed Fate的文本加入更新队列
# 将Searing Spear Askari的文本加入更新队列
# 将Seedling Charm的文本加入更新队列
# 将Seeds of Innocence的文本加入更新队列
# 将Serene Heart的文本加入更新队列
# 将Sewer Rats的文本加入更新队列
# 将Shadow Guildmage的文本加入更新队列
# 将Shadowbane的文本加入更新队列
# 将Shallow Grave的文本加入更新队列
# 将Shaper Guildmage的文本加入更新队列
# 将Shauku's Minion的文本加入更新队列
# 将Shauku, Endbringer的文本加入更新队列
# 将Shimmer的文本加入更新队列
# 将Sidar Jabari的文本加入更新队列
# 将Sirocco的文本加入更新队列
# 将Skulking Ghost的文本加入更新队列
# 将Sky Diamond的文本加入更新队列
# 将Soar的文本加入更新队列
# 将Soul Echo的文本加入更新队列
# 将Soul Rend的文本加入更新队列
# 将Soulshriek的文本加入更新队列
# 将Spatial Binding的文本加入更新队列
# 将Spectral Guardian的文本加入更新队列
# 将Spirit of the Night的文本加入更新队列
# 将Spitting Earth的文本加入更新队列
# 将Stalking Tiger的文本加入更新队列
# 将Subterranean Spirit的文本加入更新队列
# 将Sunweb的文本加入更新队列
# 将Superior Numbers的文本加入更新队列
# 将Suq'Ata Firewalker的文本加入更新队列
# 将Tainted Specter的文本加入更新队列
# 将Talruum Minotaur的文本加入更新队列
# 将Taniwha的文本加入更新队列
# 将Teeka's Dragon的文本加入更新队列
# 将Teferi's Curse的文本加入更新队列
# 将Teferi's Drake的文本加入更新队列
# 将Teferi's Imp的文本加入更新队列
# 将Teferi's Isle的文本加入更新队列
# 将Telim'Tor的文本加入更新队列
# 将Telim'Tor's Darts的文本加入更新队列
# 将Telim'Tor's Edict的文本加入更新队列
# 将Teremko Griffin的文本加入更新队列
# 将Thirst的文本加入更新队列
# 将Tidal Wave的文本加入更新队列
# 将Tombstone Stairwell的文本加入更新队列
# 将Torrent of Lava的文本加入更新队列
# 将Tranquil Domain的文本加入更新队列
# 将Tropical Storm的文本加入更新队列
# 将Uktabi Faerie的文本加入更新队列
# 将Uktabi Wildcats的文本加入更新队列
# 将Unerring Sling的文本加入更新队列
# 将Unfulfilled Desires的文本加入更新队列
# 将Unseen Walker的文本加入更新队列
# 将Unyaro Bee Sting的文本加入更新队列
# 将Unyaro Griffin的文本加入更新队列
# 将Urborg Panther的文本加入更新队列
# 将Vaporous Djinn的文本加入更新队列
# 将Ventifact Bottle的文本加入更新队列
# 将Vigilant Martyr的文本加入更新队列
# 将Village Elder的文本加入更新队列
# 将Vitalizing Cascade的文本加入更新队列
# 将Volcanic Geyser的文本加入更新队列
# 将Waiting in the Weeds的文本加入更新队列
# 将Wall of Corpses的文本加入更新队列
# 将Wall of Resistance的文本加入更新队列
# 将Wall of Roots的文本加入更新队列
# 将Ward of Lights的文本加入更新队列
# 将Warping Wurm的文本加入更新队列
# 将Wave Elemental的文本加入更新队列
# 将Wellspring的文本加入更新队列
# 将Wild Elephant的文本加入更新队列
# 将Wildfire Emissary的文本加入更新队列
# 将Windreaper Falcon的文本加入更新队列
# 将Withering Boon的文本加入更新队列
# 将Yare的文本加入更新队列
# 将Zebra Unicorn的文本加入更新队列
# 将Zhalfirin Knight的文本加入更新队列
# 将Zirilan of the Claw的文本加入更新队列
# 将Zombie Mob的文本加入更新队列
# 将Zuberi, Golden Feather的文本加入更新队列
# 已更新Abyssal Hunter的文本
# 已更新Acidic Dagger的文本
# 已更新Afiya Grove的文本
# 已更新Afterlife的文本
# 已更新Agility的文本
# 已更新Alarum的文本
# 已更新Aleatory的文本
# 已更新Amber Prison的文本
# 已更新Amulet of Unmaking的文本
# 已更新Ancestral Memories的文本
# 已更新Armor of Thorns的文本
# 已更新Armorer Guildmage的文本
# 已更新Ashen Powder的文本
# 已更新Asmira, Holy Avenger的文本
# 已更新Auspicious Ancestor的文本
# 已更新Azimaet Drake的文本
# 已更新Bad River的文本
# 已更新Barbed Foliage的文本
# 已更新Barbed-Back Wurm的文本
# 已更新Barreling Attack的文本
# 已更新Basalt Golem的文本
# 已更新Bay Falcon的文本
# 已更新Bazaar of Wonders的文本
# 已更新Benevolent Unicorn的文本
# 已更新Benthic Djinn的文本
# 已更新Binding Agony的文本
# 已更新Blighted Shaman的文本
# 已更新Blind Fury的文本
# 已更新Blistering Barrier的文本
# 已更新Bone Harvest的文本
# 已更新Bone Mask的文本
# 已更新Breathstealer的文本
# 已更新Brushwagg的文本
# 已更新Builder's Bane的文本
# 已更新Burning Palm Efreet的文本
# 已更新Burning Shield Askari的文本
# 已更新Cadaverous Bloom的文本
# 已更新Cadaverous Knight的文本
# 已更新Canopy Dragon的文本
# 已更新Carrion的文本
# 已更新Catacomb Dragon的文本
# 已更新Celestial Dawn的文本
# 已更新Cerulean Wyvern的文本
# 已更新Chaos Charm的文本
# 已更新Chaosphere的文本
# 已更新Charcoal Diamond的文本
# 已更新Chariot of the Sun的文本
# 已更新Choking Sands的文本
# 已更新Cinder Cloud的文本
# 已更新Circle of Despair的文本
# 已更新Civic Guildmage的文本
# 已更新Cloak of Invisibility的文本
# 已更新Consuming Ferocity的文本
# 已更新Coral Fighters的文本
# 已更新Crash of Rhinos的文本
# 已更新Crimson Hellkite的文本
# 已更新Crimson Roc的文本
# 已更新Crypt Cobra的文本
# 已更新Crystal Golem的文本
# 已更新Crystal Vein的文本
# 已更新Cycle of Life的文本
# 已更新Daring Apprentice的文本
# 已更新Dazzling Beauty的文本
# 已更新Decomposition的文本
# 已更新Delirium的文本
# 已更新Dirtwater Wraith的文本
# 已更新Discordant Spirit的文本
# 已更新Disempower的文本
# 已更新Divine Retribution的文本
# 已更新Dread Specter的文本
# 已更新Dream Cache的文本
# 已更新Dream Fighter的文本
# 已更新Dwarven Miner的文本
# 已更新Dwarven Nomad的文本
# 已更新Early Harvest的文本
# 已更新Ebony Charm的文本
# 已更新Ekundu Cyclops的文本
# 已更新Elixir of Vitality的文本
# 已更新Emberwilde Caliph的文本
# 已更新Emberwilde Djinn的文本
# 已更新Energy Bolt的文本
# 已更新Energy Vortex的文本
# 已更新Enfeeblement的文本
# 已更新Ersatz Gnomes的文本
# 已更新Ether Well的文本
# 已更新Ethereal Champion的文本
# 已更新Favorable Destiny的文本
# 已更新Femeref Archers的文本
# 已更新Femeref Healer的文本
# 已更新Femeref Knight的文本
# 已更新Fetid Horror的文本
# 已更新Final Fortune的文本
# 已更新Fire Diamond的文本
# 已更新Flame Elemental的文本
# 已更新Flood Plain的文本
# 已更新Floodgate的文本
# 已更新Foratog的文本
# 已更新Forbidden Crypt的文本
# 已更新Forsaken Wastes的文本
# 已更新Frenetic Efreet的文本
# 已更新Gibbering Hyenas的文本
# 已更新Goblin Elite Infantry的文本
# 已更新Goblin Scouts的文本
# 已更新Goblin Soothsayer的文本
# 已更新Goblin Tinkerer的文本
# 已更新Granger Guildmage的文本
# 已更新Grasslands的文本
# 已更新Grave Servitude的文本
# 已更新Gravebane Zombie的文本
# 已更新Grim Feast的文本
# 已更新Grinning Totem的文本
# 已更新Hakim, Loreweaver的文本
# 已更新Hall of Gemstone的文本
# 已更新Hammer of Bogardan的文本
# 已更新Harbinger of Night的文本
# 已更新Harbor Guardian的文本
# 已更新Harmattan Efreet的文本
# 已更新Haunting Apparition的文本
# 已更新Hazerider Drake的文本
# 已更新Hivis of the Scale的文本
# 已更新Horrible Hordes的文本
# 已更新Igneous Golem的文本
# 已更新Illicit Auction的文本
# 已更新Illumination的文本
# 已更新Iron Tusk Elephant的文本
# 已更新Ivory Charm的文本
# 已更新Jabari's Influence的文本
# 已更新Jolrael's Centaur的文本
# 已更新Jolt的文本
# 已更新Jungle Patrol的文本
# 已更新Jungle Troll的文本
# 已更新Jungle Wurm的文本
# 已更新Kaervek's Hex的文本
# 已更新Kaervek's Purge的文本
# 已更新Kaervek's Torch的文本
# 已更新Karoo Meerkat的文本
# 已更新Kukemssa Pirates的文本
# 已更新Kukemssa Serpent的文本
# 已更新Lead Golem的文本
# 已更新Leering Gargoyle的文本
# 已更新Lightning Reflexes的文本
# 已更新Lion's Eye Diamond的文本
# 已更新Locust Swarm的文本
# 已更新Lure of Prey的文本
# 已更新Malignant Growth的文本
# 已更新Mana Prism的文本
# 已更新Mangara's Blessing的文本
# 已更新Mangara's Equity的文本
# 已更新Mangara's Tome的文本
# 已更新Marble Diamond的文本
# 已更新Maro的文本
# 已更新Meddle的文本
# 已更新Melesse Spirit的文本
# 已更新Merfolk Raiders的文本
# 已更新Merfolk Seer的文本
# 已更新Mind Bend的文本
# 已更新Mind Harness的文本
# 已更新Mindbender Spores的文本
# 已更新Mire Shade的文本
# 已更新Misers' Cage的文本
# 已更新Mist Dragon的文本
# 已更新Moss Diamond的文本
# 已更新Mountain Valley的文本
# 已更新Mtenda Griffin的文本
# 已更新Mtenda Herder的文本
# 已更新Mtenda Lion的文本
# 已更新Natural Balance的文本
# 已更新Nettletooth Djinn的文本
# 已更新Noble Elephant的文本
# 已更新Null Chamber的文本
# 已更新Patagia Golem的文本
# 已更新Paupers' Cage的文本
# 已更新Pearl Dragon的文本
# 已更新Phyrexian Dreadnought的文本
# 已更新Phyrexian Purge的文本
# 已更新Phyrexian Tribute的文本
# 已更新Political Trickery的文本
# 已更新Polymorph的文本
# 已更新Preferred Selection的文本
# 已更新Prismatic Boon的文本
# 已更新Prismatic Circle的文本
# 已更新Prismatic Lace的文本
# 已更新Psychic Transfer的文本
# 已更新Purgatory的文本
# 已更新Purraj of Urborg的文本
# 已更新Pyric Salamander的文本
# 已更新Quirion Elves的文本
# 已更新Radiant Essence的文本
# 已更新Raging Spirit的文本
# 已更新Rashida Scalebane的文本
# 已更新Ravenous Vampire的文本
# 已更新Razor Pendulum的文本
# 已更新Reality Ripple的文本
# 已更新Reckless Embermage的文本
# 已更新Reflect Damage的文本
# 已更新Reign of Chaos的文本
# 已更新Reign of Terror的文本
# 已更新Reparations的文本
# 已更新Restless Dead的文本
# 已更新Ritual of Steel的文本
# 已更新Rock Basilisk的文本
# 已更新Rocky Tar Pit的文本
# 已更新Roots of Life的文本
# 已更新Sabertooth Cobra的文本
# 已更新Sacred Mesa的文本
# 已更新Sand Golem的文本
# 已更新Sandbar Crocodile的文本
# 已更新Sapphire Charm的文本
# 已更新Savage Twister的文本
# 已更新Sawback Manticore的文本
# 已更新Sea Scryer的文本
# 已更新Sealed Fate的文本
# 已更新Searing Spear Askari的文本
# 已更新Seedling Charm的文本
# 已更新Seeds of Innocence的文本
# 已更新Serene Heart的文本
# 已更新Sewer Rats的文本
# 已更新Shadow Guildmage的文本
# 已更新Shadowbane的文本
# 已更新Shallow Grave的文本
# 已更新Shaper Guildmage的文本
# 已更新Shauku's Minion的文本
# 已更新Shauku, Endbringer的文本
# 已更新Shimmer的文本
# 已更新Sidar Jabari的文本
# 已更新Sirocco的文本
# 已更新Skulking Ghost的文本
# 已更新Sky Diamond的文本
# 已更新Soar的文本
# 已更新Soul Echo的文本
# 已更新Soul Rend的文本
# 已更新Soulshriek的文本
# 已更新Spatial Binding的文本
# 已更新Spectral Guardian的文本
# 已更新Spirit of the Night的文本
# 已更新Spitting Earth的文本
# 已更新Stalking Tiger的文本
# 已更新Subterranean Spirit的文本
# 已更新Sunweb的文本
# 已更新Superior Numbers的文本
# 已更新Suq'Ata Firewalker的文本
# 已更新Tainted Specter的文本
# 已更新Talruum Minotaur的文本
# 已更新Taniwha的文本
# 已更新Teeka's Dragon的文本
# 已更新Teferi's Curse的文本
# 已更新Teferi's Drake的文本
# 已更新Teferi's Imp的文本
# 已更新Teferi's Isle的文本
# 已更新Telim'Tor的文本
# 已更新Telim'Tor's Darts的文本
# 已更新Telim'Tor's Edict的文本
# 已更新Teremko Griffin的文本
# 已更新Thirst的文本
# 已更新Tidal Wave的文本
# 已更新Tombstone Stairwell的文本
# 已更新Torrent of Lava的文本
# 已更新Tranquil Domain的文本
# 已更新Tropical Storm的文本
# 已更新Uktabi Faerie的文本
# 已更新Uktabi Wildcats的文本
# 已更新Unerring Sling的文本
# 已更新Unfulfilled Desires的文本
# 已更新Unseen Walker的文本
# 已更新Unyaro Bee Sting的文本
# 已更新Unyaro Griffin的文本
# 已更新Urborg Panther的文本
# 已更新Vaporous Djinn的文本
# 已更新Ventifact Bottle的文本
# 已更新Vigilant Martyr的文本
# 已更新Village Elder的文本
# 已更新Vitalizing Cascade的文本
# 已更新Volcanic Geyser的文本
# 已更新Waiting in the Weeds的文本
# 已更新Wall of Corpses的文本
# 已更新Wall of Resistance的文本
# 已更新Wall of Roots的文本
# 已更新Ward of Lights的文本
# 已更新Warping Wurm的文本
# 已更新Wave Elemental的文本
# 已更新Wellspring的文本
# 已更新Wild Elephant的文本
# 已更新Wildfire Emissary的文本
# 已更新Windreaper Falcon的文本
# 已更新Withering Boon的文本
# 已更新Yare的文本
# 已更新Zebra Unicorn的文本
# 已更新Zhalfirin Knight的文本
# 已更新Zirilan of the Claw的文本
# 已更新Zombie Mob的文本
# 已更新Zuberi, Golden Feather的文本
# 更新完成，更新了0个牌名，291个文本

# %% [markdown]
# ## 以下代码从数据库中读取数据并生成xliff文件

# %%
def export_xliff(sql_text, file_suffix):
    data = read_table(sql_text)

    EN_DIR = f"{WORKDIR}/project/lang/en"
    ZH_DIR = f"{WORKDIR}/project/lang/zh_Hans"

    sorted_data = sort_data_by_set(data)
    
    for set_code in sorted_data:
        en_tree, en_body = create_xliff_tree()
        zh_tree, zh_body = create_xliff_tree()

        for unit in sorted_data[set_code]:
            add_trans_unit(en_body, zh_body, unit)

        en_tree = etree.ElementTree(en_tree)
        zh_tree = etree.ElementTree(zh_tree)

        # if set_code == "CON": set_code = "CON_" # For some windows reasons
        
        en_tree.write(f"{EN_DIR}/{set_code}-{file_suffix}.xliff", pretty_print=True, xml_declaration=True, encoding="utf-8")
        zh_tree.write(f"{ZH_DIR}/{set_code}-{file_suffix}.xliff", pretty_print=True, xml_declaration=True, encoding="utf-8")

        print(f"Set {set_code} done.")

export_xliff(ATOMIC_SQL_TEXT, "Oracle")
export_xliff(ALL_SQL_TEXT, "Printed")
